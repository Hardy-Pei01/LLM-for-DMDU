# %% [markdown]
# # Lake 1

# %% [markdown]
# ## A summary of important components
#
# | Steps | Global state variables | Global control variables | Global transition functions | Global objective functions | Global stochastic variables | Global deeply uncertain variables/parameters | Global constants | Global constraints | Perspective-specific state variables | Perspective-specific control variables | Perspective-specific transition functions | Perspective-specific objective functions | Perspective-specific constants | Perspective-specific constraints | Total |
# | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: |
# | 1 | 1 | 1 | 1 | 1 | 1 | 6 | 1 | 2 | 0 | 0 | 0 | 0 | 0 | 0 | 14 |
# | 2 | 1 | 0 | 1 | 0 | 1 | 6 | 1 | 2 | 0 | 5 | 1 | 9 | 0 | 1 | 28 |
# | 3 | 1 | 1 | 1 | 0 | 1 | 6 | 1 | 7 | 0 | 4 | 0 | 9 | 0 | 0 | 31 |

# %%
import pandas as pd
s1 = pd.Series([1, 1, 1, 1, 1, 6, 1, 2, 0, 0, 0, 0, 0, 0, 14])
s2 = pd.Series([1, 0, 1, 0, 1, 6, 1, 2, 0, 5, 1, 9, 0, 1, 28])
s3 = pd.Series([1, 1, 1, 0, 1, 6, 1, 7, 0, 4, 0, 9, 0, 0, 31])
market_1 = df = pd.DataFrame([list(s1), list(s2), list(s3)],  columns =  ["Global state variables", 
                                                                          "Global control variables", 
                                                                          "Global transition functions", 
                                                                          "Global objective functions", 
                                                                          "Global stochastic variables", 
                                                                          "Global deeply uncertain variables/parameters", 
                                                                          "Global constants", 
                                                                          "Global constraints", 
                                                                          "Perspective-specific state variables", 
                                                                          "Perspective-specific control variables", 
                                                                          "Perspective-specific transition functions", 
                                                                          "Perspective-specific objective functions", 
                                                                          "Perspective-specific constants", "Perspective-specific constraints", 
                                                                          "Total"])

# %% [markdown]
# # Lake 2

# %% [markdown]
# ## A summary of important components
#
# | Steps | Global state variables | Global control variables | Global transition functions | Global objective functions | Global stochastic variables | Global deeply uncertain variables/parameters | Global constants | Global constraints | Perspective-specific state variables | Perspective-specific control variables | Perspective-specific transition functions | Perspective-specific objective functions | Perspective-specific constants | Perspective-specific constraints | Total |
# | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: |
# | 1 | 1 | 1 | 1 | 1 | 1 | 6 | 1 | 3 | 0 | 0 | 0 | 0 | 0 | 0 | 15 |
# | 2 | 1 | 0 | 1 | 0 | 1 | 6 | 1 | 0 | 0 | 4 | 0 | 8 | 5 | 1 | 28 |
# | 3 | 1 | 1 | 1 | 0 | 1 | 6 | 3 | 8 | 0 | 4 | 0 | 8 | 5 | 1 | 39 |

# %%
import pandas as pd
s1 = pd.Series([1, 1, 1, 1, 1, 6, 1, 3, 0, 0, 0, 0, 0, 0, 15])
s2 = pd.Series([1, 0, 1, 0, 1, 6, 1, 0, 0, 4, 0, 8, 5, 1, 28])
s3 = pd.Series([1, 1, 1, 0, 1, 6, 3, 8, 0, 4, 0, 8, 5, 1, 39])
market_2 = df = pd.DataFrame([list(s1), list(s2), list(s3)],  columns =  ["Global state variables", 
                                                                          "Global control variables", 
                                                                          "Global transition functions", 
                                                                          "Global objective functions", 
                                                                          "Global stochastic variables", 
                                                                          "Global deeply uncertain variables/parameters", 
                                                                          "Global constants", 
                                                                          "Global constraints", 
                                                                          "Perspective-specific state variables", 
                                                                          "Perspective-specific control variables", 
                                                                          "Perspective-specific transition functions", 
                                                                          "Perspective-specific objective functions", 
                                                                          "Perspective-specific constants", "Perspective-specific constraints", 
                                                                          "Total"])

# %% [markdown]
# # Lake 3

# %% [markdown]
# ## A summary of important components
#
# | Steps | Global state variables | Global control variables | Global transition functions | Global objective functions | Global stochastic variables | Global deeply uncertain variables/parameters | Global constants | Global constraints | Perspective-specific state variables | Perspective-specific control variables | Perspective-specific transition functions | Perspective-specific objective functions | Perspective-specific constants | Perspective-specific constraints | Total |
# | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: |
# | 1 | 1 | 1 | 1 | 1 | 1 | 6 | 1 | 2 | 0 | 0 | 0 | 0 | 0 | 0 | 14 |
# | 2 | 1 | 0 | 1 | 0 | 1 | 6 | 1 | 0 | 0 | 4 | 0 | 7 | 1 | 1 | 23 |
# | 3 | 1 | 1 | 1 | 0 | 1 | 6 | 1 | 0 | 0 | 4 | 4 | 9 | 3 | 5 | 36 |

# %%
import pandas as pd
s1 = pd.Series([1, 1, 1, 1, 1, 6, 1, 2, 0, 0, 0, 0, 0, 0, 14])
s2 = pd.Series([1, 0, 1, 0, 1, 6, 1, 0, 0, 4, 0, 7, 1, 1, 23])
s3 = pd.Series([1, 1, 1, 0, 1, 6, 1, 0, 0, 4, 4, 9, 3, 5, 36])
market_3 = df = pd.DataFrame([list(s1), list(s2), list(s3)],  columns =  ["Global state variables", 
                                                                          "Global control variables", 
                                                                          "Global transition functions", 
                                                                          "Global objective functions", 
                                                                          "Global stochastic variables", 
                                                                          "Global deeply uncertain variables/parameters", 
                                                                          "Global constants", 
                                                                          "Global constraints", 
                                                                          "Perspective-specific state variables", 
                                                                          "Perspective-specific control variables", 
                                                                          "Perspective-specific transition functions", 
                                                                          "Perspective-specific objective functions", 
                                                                          "Perspective-specific constants", "Perspective-specific constraints", 
                                                                          "Total"])

# %% [markdown]
# # Lake 4

# %% [markdown]
# ## A summary of important components
#
# | Steps | Global state variables | Global control variables | Global transition functions | Global objective functions | Global stochastic variables | Global deeply uncertain variables/parameters | Global constants | Global constraints | Perspective-specific state variables | Perspective-specific control variables | Perspective-specific transition functions | Perspective-specific objective functions | Perspective-specific constants | Perspective-specific constraints | Total |
# | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: |
# | 1 | 1 | 1 | 1 | 1 | 1 | 6 | 1 | 3 | 0 | 0 | 0 | 0 | 0 | 0 | 15 |
# | 2 | 1 | 0 | 1 | 0 | 1 | 6 | 1 | 0 | 0 | 4 | 2 | 7 | 5 | 2 | 30 |
# | 3 | 1 | 1 | 1 | 0 | 1 | 6 | 2 | 8 | 0 | 5 | 0 | 7 | 5 | 0 | 37 |

# %%
import pandas as pd
s1 = pd.Series([1, 1, 1, 1, 1, 6, 1, 3, 0, 0, 0, 0, 0, 0, 15])
s2 = pd.Series([1, 0, 1, 0, 1, 6, 1, 0, 0, 4, 2, 7, 5, 2, 30])
s3 = pd.Series([1, 1, 1, 0, 1, 6, 2, 8, 0, 5, 0, 7, 5, 0, 37])
market_4 = df = pd.DataFrame([list(s1), list(s2), list(s3)],  columns =  ["Global state variables", 
                                                                          "Global control variables", 
                                                                          "Global transition functions", 
                                                                          "Global objective functions", 
                                                                          "Global stochastic variables", 
                                                                          "Global deeply uncertain variables/parameters", 
                                                                          "Global constants", 
                                                                          "Global constraints", 
                                                                          "Perspective-specific state variables", 
                                                                          "Perspective-specific control variables", 
                                                                          "Perspective-specific transition functions", 
                                                                          "Perspective-specific objective functions", 
                                                                          "Perspective-specific constants", "Perspective-specific constraints", 
                                                                          "Total"])

# %% [markdown]
# # Summary

# %% [markdown]
# ## Number of components

# %%
import matplotlib.pyplot as plt
import numpy as np

x_ticks = [1,2,3]
plt.plot(x_ticks, market_1["Total"], label="Trial 1")
plt.plot(x_ticks, market_2["Total"], label="Trial 2")
plt.plot(x_ticks, market_3["Total"], label="Trial 3")
plt.plot(x_ticks, market_4["Total"], label="Trial 4")

plt.xticks(x_ticks)
plt.xlabel("Steps")
plt.ylabel("Number of components")
plt.legend()
plt.show()

# %% [markdown]
# # Python run

# %%
trial_one = [0.0, 0.06149004155109629, 0.08896338980633783, 0.12878963779217803, 0.12725829696643476, 0.12509850128239594, 0.1213645253680157, 0.14745095360254565, 0.16230597129353597, 0.18767577239417665, 0.19370706534048537, 0.2115746934837175, 0.2281050205870151, 0.24824306323948986, 0.26603076895190736, 0.26513616800812023, 0.2617702086264718, 0.27762706500267065, 0.2799043533089161, 0.27684506789904817, 0.3015779025826583, 0.3414075245817239, 0.3614258946624906, 0.40682009152995663, 0.44763276041500416, 0.49672990074767637, 0.5350109424194409, 0.5638698317051706, 0.6086375248722886, 0.6765173966973169, 0.7503053490839842, 0.8686733019789181, 1.0014349769482664, 1.1316706729232089, 1.2610978527112082, 1.3910566342037034, 1.5089085018258648, 1.6439811315067256, 1.7343132109163208, 1.8220258970980443, 1.874416911867832, 1.9076642227433025, 1.9397626070138585, 1.978613638484905, 1.9723002653232744, 1.9999161246076154, 2.003222073880004, 2.0412981012531133, 2.048148909300869, 2.0690855082175488, 2.0916710950381168, 2.1150806152828814, 2.099335629439658, 2.097705766065134, 2.09385900230544, 2.0779762550108236, 2.094785805415719, 2.1097054445776835, 2.09115566759455, 2.069962384752685, 2.0745205509618985, 2.0475018988903, 2.038913086174375, 2.0633264139915104, 2.091566170082059, 2.064350762445728, 2.039199405046281, 2.035371191140182, 2.0102746543382586, 2.0106585442301776, 2.0185610764502173, 2.0526650663748423, 2.0366876121371456, 2.0344410447422763, 2.023201288022948, 2.0790139110423476, 2.0607048808961874, 2.07822545452727, 2.0825430963756792, 2.0581559892267065, 2.0266343212048725, 2.024917632372318, 2.0125494671718727, 2.0571122674463127, 2.075699596571558, 2.0620710218661102, 2.079022864346235, 2.090084323989856, 2.097396013680289, 2.1070156991757356, 2.114595417986612, 2.0989732810314203, 2.099155382204435, 2.0682381126193397, 2.070673658653328, 2.075526134564024, 2.0651100012592556, 2.057050645994441, 2.054234386662086, 2.0669919014833105, 2.042427524763971]
