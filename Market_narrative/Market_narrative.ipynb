# %% [markdown]
# # Market 1

# %% [markdown]
# ## A summary of important components
#
# | Steps | Global state variables | Global control variables | Global transition functions | Global objective functions | Global stochastic variables | Global deeply uncertain variables/parameters | Global constants | Global constraints | Perspective-specific state variables | Perspective-specific control variables | Perspective-specific transition functions | Perspective-specific objective functions | Perspective-specific constants | Perspective-specific constraints | Total |
# | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: |
# | 1 | 0 | 2 | 1 | 1 | 8 | 1 | 16 | 2 | 0 | 0 | 0 | 0 | 0 | 0 | 31 |
# | 2 | 5 | 0 | 1 | 0 | 8 | 1 | 16 | 0 | 2 | 6 | 2 | 9 | 1 | 0 | 51 |
# | 2 | 6 | 0 | 1 | 0 | 8 | 1 | 16 | 0 | 2 | 6 | 2 | 9 | 1 | 0 | 52 |

# %%
import pandas as pd
s1 = pd.Series([0, 2, 1, 1, 8, 1, 16, 2, 0, 0, 0, 0, 0, 0, 31])
s2 = pd.Series([5, 0, 1, 0, 8, 1, 16, 0, 2, 6, 2, 9, 1, 0, 51])
s3 = pd.Series([6, 0, 1, 0, 8, 1, 16, 0, 2, 6, 2, 9, 1, 0, 52])
market_1 = df = pd.DataFrame([list(s1), list(s2), list(s3)],  columns =  ["Global state variables", 
                                                                          "Global control variables", 
                                                                          "Global transition functions", 
                                                                          "Global objective functions", 
                                                                          "Global stochastic variables", 
                                                                          "Global deeply uncertain variables/parameters", 
                                                                          "Global constants", 
                                                                          "Global constraints", 
                                                                          "Perspective-specific state variables", 
                                                                          "Perspective-specific control variables", 
                                                                          "Perspective-specific transition functions", 
                                                                          "Perspective-specific objective functions", 
                                                                          "Perspective-specific constants", "Perspective-specific constraints", 
                                                                          "Total"])

# %% [markdown]
# # Market 2

# %% [markdown]
# ## A summary of important components
#
# | Steps | Global state variables | Global control variables | Global transition functions | Global objective functions | Global stochastic variables | Global deeply uncertain variables/parameters | Global constants | Global constraints | Perspective-specific state variables | Perspective-specific control variables | Perspective-specific transition functions | Perspective-specific objective functions | Perspective-specific constants | Perspective-specific constraints | Total |
# | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: |
# | 1 | 0 | 2 | 1 | 1 | 8 | 1 | 16 | 4 | 0 | 0 | 0 | 0 | 0 | 0 | 33 |
# | 2 | 8 | 0 | 1 | 0 | 8 | 1 | 16 | 0 | 2 | 4 | 2 | 10 | 0 | 2 | 54 |
# | 3 | 8 | 0 | 1 | 0 | 8 | 1 | 16 | 0 | 2 | 4 | 2 | 10 | 0 | 2 | 54 |

# %%
s1 = pd.Series([0, 2, 1, 1, 8, 1, 16, 4, 0, 0, 0, 0, 0, 0, 33])
s2 = pd.Series([8, 0, 1, 0, 8, 1, 16, 0, 2, 4, 2, 10, 0, 2, 54])
s3 = pd.Series([8, 0, 1, 0, 8, 1, 16, 0, 2, 4, 2, 10, 0, 2, 54])
market_2 = df = pd.DataFrame([list(s1), list(s2), list(s3)],  columns =  ["Global state variables", 
                                                                          "Global control variables", 
                                                                          "Global transition functions", 
                                                                          "Global objective functions", 
                                                                          "Global stochastic variables", 
                                                                          "Global deeply uncertain variables/parameters", 
                                                                          "Global constants", 
                                                                          "Global constraints", 
                                                                          "Perspective-specific state variables", 
                                                                          "Perspective-specific control variables", 
                                                                          "Perspective-specific transition functions", 
                                                                          "Perspective-specific objective functions", 
                                                                          "Perspective-specific constants", "Perspective-specific constraints", 
                                                                          "Total"])

# %% [markdown]
# # Market 3

# %% [markdown]
# ## A summary of important components
#
# | Steps | Global state variables | Global control variables | Global transition functions | Global objective functions | Global stochastic variables | Global deeply uncertain variables/parameters | Global constants | Global constraints | Perspective-specific state variables | Perspective-specific control variables | Perspective-specific transition functions | Perspective-specific objective functions | Perspective-specific constants | Perspective-specific constraints | Total |
# | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: | :-: |
# | 1 | 0 | 2 | 1 | 1 | 8 | 1 | 16 | 2 | 0 | 0 | 0 | 0 | 0 | 0 | 31 |
# | 2 | 9 | 0 | 1 | 0 | 8 | 1 | 16 | 0 | 2 | 4 | 2 | 7 | 0 | 2 | 52 |
# | 3 | 9 | 0 | 1 | 0 | 8 | 1 | 16 | 0 | 2 | 4 | 2 | 7 | 0 | 2 | 52 |

# %%
s1 = pd.Series([0, 2, 1, 1, 8, 1, 16, 2, 0, 0, 0, 0, 0, 0, 31])
s2 = pd.Series([9, 0, 1, 0, 8, 1, 16, 0, 2, 4, 2, 7, 0, 2, 52])
s3 = pd.Series([9, 0, 1, 0, 8, 1, 16, 0, 2, 4, 2, 7, 0, 2, 52])
market_3 = df = pd.DataFrame([list(s1), list(s2), list(s3)],  columns =  ["Global state variables", 
                                                                          "Global control variables", 
                                                                          "Global transition functions", 
                                                                          "Global objective functions", 
                                                                          "Global stochastic variables", 
                                                                          "Global deeply uncertain variables/parameters", 
                                                                          "Global constants", 
                                                                          "Global constraints", 
                                                                          "Perspective-specific state variables", 
                                                                          "Perspective-specific control variables", 
                                                                          "Perspective-specific transition functions", 
                                                                          "Perspective-specific objective functions", 
                                                                          "Perspective-specific constants", "Perspective-specific constraints", 
                                                                          "Total"])

# %% [markdown]
# # Summary

# %% [markdown]
# ## Number of components

# %%
import matplotlib.pyplot as plt
import numpy as np

x_ticks = [1,2,3]
plt.plot(x_ticks, market_1["Total"], label="Trial 1")
plt.plot(x_ticks, market_2["Total"], label="Trial 2")
plt.plot(x_ticks, market_3["Total"], label="Trial 3")

plt.xticks(x_ticks)
plt.xlabel("Steps")
plt.ylabel("Number of components")
plt.legend()
plt.show()

# %% [markdown]
# # Python run

# %%
trial_one_run = [868.7439675558725, 1050.8256675209093, 727.3947623836121, 1101.7711545706852, 976.6349782127493, 829.6377974352504, 934.5211480214764, 393.58173879569495, 148.18667460688732, 802.9164700577635, 1060.6044401064646, 552.1706248581983, 936.5321389234875, 220.5762556704235, 603.9371373060527, 535.1183662317724, 535.4914998707407, 1087.870528303064, 568.7144989110043, 453.409307566286, 1059.895127773245, 246.6395611657622, 461.88424146457385, 978.0531522852538]
trial_two_run = [900.6441712614054, 790.8867099050334, 789.6592056214894, 721.5611084945161, 958.257929527674, 615.1285908165526, 1021.728976476301, 876.457416639721, 647.1821443115168, 706.8642517255814, 827.9133411055722, 714.005821620441, 678.1710326261036, 853.1337041959687, 820.2771080594584, 970.497531484812, 750.4351275927615, 1016.9800599376067, 1005.1399754952951, 826.4014492824087, 805.5843547265497, 829.917501333183, 670.6068260178675, 914.850554797488]
trial_three_run = [991.6219054847957, 815.344140802165, 1034.9438455621116, 824.332035733815, 913.0994523619232, 830.6231620650577, 806.7644601234041, 781.1311623533851, 1010.2972996046392, 836.1834353973843, 885.0554291572585, 825.0751712631676, 862.4972867100591, 952.9604521659076, 897.3742374927535, 913.0814644382741, 898.5786740512478, 727.1183086729915, 963.0906203437269, 738.3215953930325, 1077.1567916122528, 729.2983870450083, 646.7480509467775, 565.3761206926395]
trial_four_run = [549.2700491857896, 1129.6943643705126, 1350.4666734753796, 1180.9331836575013, 1313.4656441890143, 1091.547657137692, 925.561248408798, 1021.3711248153156, 1308.3585073380063, 1184.6377447314467, 1052.4190309461799, 432.1673855311119, 730.4121656851148, 1278.8695656624288, 1265.903076610016, 650.4236896750965, 1223.898632320486, 1259.0795439799535, 1398.222221133101, 901.4787731745935, 1135.7915700725105, 1158.3245959078215, 1042.406548815736, 1188.6622230916548]

plt.plot(trial_one_run, label="Trial 1")
plt.plot(trial_two_run, label="Trial 2")
plt.plot(trial_three_run, label="Trial 3")
plt.plot(trial_four_run, label="Trial 4")
plt.xlabel("Time steps")
plt.ylabel("Current profit for the renewable producer")
plt.legend()
plt.show()
